# %% [markdown]
# #__User-Based Collaborative Filtering__
#
# Let's explore how to create collaborative filtering based on users.

# %% [markdown]
# ## Step 1: Import Required Libraries
#
# - Import pandas, NumPy, scipy.stats, seaborn, and cosine_similarity
# - Import Matplotlib for visualization

# %%
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Step 2: Load and Preprocess the Data
#
# - Read the CSV files containing the anime and rating data
# - Filter the ratings data
# - Check the number of ratings, unique users, and unique animes

# %% [markdown]
# - We are using 2 datasets here:
# 1.   anime
# 2.   rating

# %%
animes = pd.read_csv('../../Datasets/anime.csv')

# %%
ratings = pd.read_csv('../../Datasets/ratings.csv')

# %% [markdown]
# - In rating, we have a few people who did not rate.
# - Let's not consider that.

# %%
ratings = ratings[ratings.rating != -1]
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# __Observations:__
# - Here, you can see a few rows from the rating data.
# - The fields are user_id, anime_id, and rating.

# %%
animes.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %% [markdown]
# __Observations:__
# - Here, you can see the top five observations about anime.
# - The fields are anime_id, name, genre, type, episodes, rating, and members.

# %% [markdown]
# ## Step 3: Data Exploration
#
# - Calculate and visualize the average number of anime rated per user
# - Calculate and visualize the average number of ratings given per anime

# %%
len(ratings)
# Out:
# 100836

# %% [markdown]
# __Observation:__
# - The length of the rating is 509577.

# %%
len(ratings['userId'].unique())
# Out:
# 610

# %% [markdown]
# __Observation:__
# - There are 5726 old users.

# %%
len(animes)
# Out:
# 12294

# %%
len(animes['anime_id'].unique())
# Out:
# 12294

# %% [markdown]
# __Observation:__
# - There are 12294 unique anime IDs.
# - Import statistics
# - Group by ratings per user

# %%
import statistics
ratings_per_user = ratings.groupby('userId')['rating'].count()
statistics.mean(ratings_per_user.tolist())
# Out:
# 165.30491803278687

# %% [markdown]
# __Observation:__
# - On average, there are 88 ratings per user.

# %% [markdown]
# Create a per-user rating histogram

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ratings_per_user.hist(bins=20, range=(0,500))
# Out:
# <Axes: >

# %% [markdown]
# __Observations:__
# - Here, we can see the histogram based on rating per user using 20 bins.
# - It is clear from the histogram that the first bin has a higher value.

# %% [markdown]
# Now, let's check the rating per anime.

# %%
ratings_per_anime = animes.groupby('anime_id')['rating'].count()
statistics.mean(ratings_per_anime.tolist())
# Out:
# 0.9812916870017895

# %% [markdown]
# __Observation:__
# - The average rating per anime is 72.075.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ratings_per_anime.hist(bins=20, range=(0,2500))
# Out:
# <Axes: >

# %% [markdown]
# __Observation:__
# - Here, we can see the histogram based on rating per anime using 20 bins.

# %% [markdown]
# Create a DataFrame per anime and a filter
#   - Filter ratings greater than 1000 to find a popular anime

# %%
ratings_per_anime_df = pd.DataFrame(ratings_per_anime)

filtered_ratings_per_anime_df = ratings_per_anime_df[ratings_per_anime_df.rating >= 1000]

popular_anime = filtered_ratings_per_anime_df.index.tolist()

# %% [markdown]
# Create ratings per user DataFrame
#   - Filter the ratings greater than 500 and create an index to list prolific users

# %%
ratings_per_user_df = pd.DataFrame(ratings_per_user)

filtered_ratings_per_user_df = ratings_per_user_df[ratings_per_user_df.rating >= 500]

prolific_users = filtered_ratings_per_user_df.index.tolist()

# %% [markdown]
# ## Step 4: Filtering the Data
#
# - Filter the data based on the number of ratings per user and per anime
# - Create a pivot table from the filtered data
# - Fill NaN values with 0 in the rating matrix

# %%
# filtered_ratings = ratings[ratings.anime_id.isin(popular_anime)]
filtered_ratings = animes[animes.anime_id.isin(popular_anime)]
# filtered_ratings = ratings[ratings.user_id.isin(prolific_users)]
filtered_ratings = ratings[ratings.userId.isin(prolific_users)]
filtered_ratings
# Out:
#         userId  movieId  rating   timestamp
# 1772        18        1     3.5  1455209816
# 1773        18        2     3.0  1455617462
# 1774        18        6     4.0  1460138360
# 1775        18       16     4.5  1461311583
# 1776        18       32     4.0  1455209840
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [40554 rows x 4 columns]

# %%
len(filtered_ratings)

# %%
rating_matrix = filtered_ratings.pivot_table(index='userId', columns='anime_id', values='rating')
rating_matrix = rating_matrix.fillna(0)
rating_matrix.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 rating_matrix = filtered_ratings.pivot_table(index='userId', columns='anime_id', values='rating')
#       2 rating_matrix = rating_matrix.fillna(0)
#       3 rating_matrix.head()
#
# File /opt/anaconda3/envs/ipykernel_py3/lib/python3.12/site-packages/pandas/core/frame.py:9496, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9479 @Substitution("")
#    9480 @Appender(_shared_docs["pivot_table"])
#    9481 def pivot_table(
#    (...)
#    9492     sort: bool = True,
#    9493 ) -> DataFrame:
#    9494     from pandas.core.reshape.pivot import pivot_table
# -> 9496     return pivot_table(
#    9497         self,
#    9498         values=values,
#    9499         index=index,
#    9500         columns=columns,
#    9501         aggfunc=aggfunc,
#    9502         fill_value=fill_value,
#    9503         margins=margins,
#    9504         dropna=dropna,
#    9505         margins_name=margins_name,
#    9506         observed=observed,
#    9507         sort=sort,
#    9508     )
#
# File /opt/anaconda3/envs/ipykernel_py3/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File /opt/anaconda3/envs/ipykernel_py3/lib/python3.12/site-packages/pandas/core/reshape/pivot.py:172, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     169     values = list(values)
#     171 observed_bool = False if observed is lib.no_default else observed
# --> 172 grouped = data.groupby(keys, observed=observed_bool, sort=sort, dropna=dropna)
#     173 if observed is lib.no_default and any(
#     174     ping._passed_categorical for ping in grouped._grouper.groupings
#     175 ):
#     176     warnings.warn(
#     177         "The default value of observed=False is deprecated and will change "
#     178         "to observed=True in a future version of pandas. Specify "
#    (...)
#     181         stacklevel=find_stack_level(),
#     182     )
#
# File /opt/anaconda3/envs/ipykernel_py3/lib/python3.12/site-packages/pandas/core/frame.py:9170, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9167 if level is None and by is None:
#    9168     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9170 return DataFrameGroupBy(
#    9171     obj=self,
#    9172     keys=by,
#    9173     axis=axis,
#    9174     level=level,
#    9175     as_index=as_index,
#    9176     sort=sort,
#    9177     group_keys=group_keys,
#    9178     observed=observed,
#    9179     dropna=dropna,
#    9180 )
#
# File /opt/anaconda3/envs/ipykernel_py3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/anaconda3/envs/ipykernel_py3/lib/python3.12/site-packages/pandas/core/groupby/grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'anime_id'

# %% [markdown]
# __Observation:__
# - The anime and user ID details are displayed above.

# %% [markdown]
# ## Step 5: Define the similar_users Function
#
# - Define a function to find similar_users based on the cosine similarity of their rating vectors

# %%
from sklearn.metrics.pairwise import cosine_similarity
import operator
def similar_users(user_id, matrix, k=3):
    user = matrix[matrix.index == user_id]
    
    other_users = matrix[matrix.index != user_id]
    
    similarities = cosine_similarity(user,other_users)[0].tolist()
    
    indices = other_users.index.tolist()
    
    index_similarity = dict(zip(indices, similarities))
    
    index_similarity_sorted = sorted(index_similarity.items(), key=operator.itemgetter(1))
    index_similarity_sorted.reverse()
    
    top_users_similarities = index_similarity_sorted[:k]
    users = [u[0] for u in top_users_similarities]
    
    return users

# %% [markdown]
# ## Step 6: Test the similar_users Function
#
# - Test the `similar_users` function with a sample user ID

# %%
current_user = 226
similar_user_indices = similar_users(current_user, rating_matrix)
print(similar_user_indices)
# Out:
# [3203, 5672, 2297]

# %% [markdown]
# __Observation:__
# - Here, we have similar indices.

# %% [markdown]
# ## Step 7: Define the recommend_item Function
#
# - Define a function to recommend items (animes) for a user based on the average ratings of similar users
# - Test the `recommend_item` function with a sample user ID and the similar user indices obtained in Step 6

# %%
def recommend_item(user_index, similar_user_indices, matrix, items=5):
    
    similar_users = matrix[matrix.index.isin(similar_user_indices)]
   
    similar_users = similar_users.mean(axis=0)
    
    similar_users_df = pd.DataFrame(similar_users, columns=['mean'])
    
    user_df = matrix[matrix.index == user_index]

    user_df_transposed = user_df.transpose()
   
    user_df_transposed.columns = ['rating']
    
    user_df_transposed = user_df_transposed[user_df_transposed['rating']==0]
   
    animes_unseen = user_df_transposed.index.tolist()
    
  
    similar_users_df_filtered = similar_users_df[similar_users_df.index.isin(animes_unseen)]
 
    similar_users_df_ordered = similar_users_df.sort_values(by=['mean'], ascending=False)
   
    top_n_anime = similar_users_df_ordered.head(items)
    top_n_anime_indices = top_n_anime.index.tolist()

    anime_information = animes[animes['anime_id'].isin(top_n_anime_indices)]
    
    return anime_information

recommend_item(226, similar_user_indices, rating_matrix)
# Out:
#       anime_id                  name  \
# 10        4181  Clannad: After Story
# 223       2167               Clannad
# 374      17265           Log Horizon
# 1348      8676            Amagami SS
# 1442     15583           Date A Live
#
#                                                   genre type episodes  rating  \
# 10    Drama, Fantasy, Romance, Slice of Life, Supern...   TV       24    9.06
# 223   Comedy, Drama, Romance, School, Slice of Life,...   TV       23    8.30
# 374    Action, Adventure, Fantasy, Game, Magic, Shounen   TV       25    8.14
# 1348             Comedy, Romance, School, Slice of Life   TV       25    7.57
# 1442      Comedy, Harem, Mecha, Romance, School, Sci-Fi   TV       12    7.54
#
#       members
# 10     456749
# 223    566690
# 374    387100
# 1348   157223
# 1442   301358

# %% [markdown]
# __Observation:__
#
# The recommendations shown above were given to the user.

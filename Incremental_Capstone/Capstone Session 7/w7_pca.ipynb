# %% [markdown]
# ## Load the dataset

# %%
# !pip install jinja2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('../../Datasets/CC General.csv')

df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %% [markdown]
# We drop the customer id from the dataset

# %%
# df.drop('CUST_ID')
del df['CUST_ID']

# %% [markdown]
# Check for missing data...

# %%
df.isna().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['MINIMUM_PAYMENTS'].value_counts()
# Out:
# MINIMUM_PAYMENTS
# 299.351881    2
# 342.286490    1
# 184.464721    1
# 276.486072    1
# 309.140865    1
#              ..
# 181.773223    1
# 711.894455    1
# 256.522546    1
# 127.799107    1
# 88.288956     1
# Name: count, Length: 8636, dtype: int64

# %%
df['MINIMUM_PAYMENTS'].describe()
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
df[df['MINIMUM_PAYMENTS'] == 0].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['CREDIT_LIMIT'].describe()
# Out:
# count     8949.000000
# mean      4494.449450
# std       3638.815725
# min         50.000000
# 25%       1600.000000
# 50%       3000.000000
# 75%       6500.000000
# max      30000.000000
# Name: CREDIT_LIMIT, dtype: float64

# %% [markdown]
# ### Fill missing data with zeros

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ## Scale data

# %% [markdown]
# create scaler

# %%
scaler = StandardScaler()

# %%
#scale the data set
scaled_df = scaler.fit_transform(df)

scaled_df
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.2973097 ,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.10204243,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.08848934,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.32175099,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.33316552,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.31923775,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# ## Perform PCA with ALL columns and plot number of components to capture 85% of variance of the original data

# %%
## Reduce the dimensions of our dataset

# create the object PCA
# this is a discovery step, we don't know how many components will be good.
pca = PCA()


pca.fit(scaled_df)
# Out:
# PCA()

# %% [markdown]
# See the principal components...

# %%
components = pca.explained_variance_ratio_
components
# Out:
# array([2.73022794e-01, 2.03198080e-01, 8.82521348e-02, 7.47922291e-02,
#        6.20419660e-02, 5.73451642e-02, 4.88066019e-02, 4.32366782e-02,
#        3.77970659e-02, 3.07995556e-02, 2.37243719e-02, 1.77334350e-02,
#        1.42870424e-02, 1.21666759e-02, 1.01251295e-02, 2.67039035e-03,
#        6.85228665e-07])

# %%
commulative = np.cumsum(components) #add the comulative values in the array
commulative
# Out:
# array([0.27302279, 0.47622087, 0.56447301, 0.63926524, 0.7013072 ,
#        0.75865237, 0.80745897, 0.85069565, 0.88849271, 0.91929227,
#        0.94301664, 0.96075008, 0.97503712, 0.98720379, 0.99732892,
#        0.99999931, 1.        ])

# %% [markdown]
# ## We can see that the first 8 components capture 85% of variance from the original dataset.

# %%
plt.plot(commulative)

# %% [markdown]
# ## Vizualize the principal components

# %%
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
loading_matrix = pd.DataFrame(loadings, index=df.columns)

loading_matrix.style.background_gradient(cmap='RdYlGn', axis=None)
# loading_matrix.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_17b7a_row0_col0 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_17b7a_row0_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_17b7a_row0_col2 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_17b7a_row0_col3, #T_17b7a_row2_col2, #T_17b7a_row14_col1 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_17b7a_row0_col4, #T_17b7a_row2_col12, #T_17b7a_row9_col5, #T_17b7a_row15_col12 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_17b7a_row0_col5, #T_17b7a_row2_col11, #T_17b7a_row7_col3, #T_17b7a_row13_col14, #T_17b7a_row16_col9, #T_17b7a_row16_col10, #T_17b7a_row16_col12 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_17b7a_row0_col6 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_17b7a_row0_col7 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Perform PCA with 2 principal components to visualize the clustering data

# %%
num_components = 2

pca_final = PCA(n_components=num_components)

pca_data = pca_final.fit_transform(scaled_df)

# %%
pca_final.get_covariance()
# Out:
# array([[ 1.10220962,  0.20218494,  0.21565445,  0.21403263,  0.11658839,
#          0.49768029, -0.08831582,  0.09983759, -0.09337626,  0.4650015 ,
#          0.46489978,  0.13761755,  0.36218775,  0.40624107,  0.22331009,
#         -0.1651304 ,  0.02868832],
#        [ 0.20218494,  0.70244058,  0.21605315,  0.1924411 ,  0.15723733,
#          0.1545438 ,  0.08479504,  0.13679379,  0.06661064,  0.12060122,
#          0.13487435,  0.18314967,  0.1933241 ,  0.22700574,  0.09587458,
#         -0.00731875,  0.03808234],
#        [ 0.21565445,  0.21605315,  1.28366443,  0.58380401,  0.55873517,
#          0.01204352,  0.51329458,  0.4883226 ,  0.43686761, -0.09803877,
#         -0.03233875,  0.64826768,  0.38013481,  0.47307059,  0.12726012,
#          0.19791   ,  0.13469138],
#        [ 0.21403263,  0.1924411 ,  0.58380401,  1.08990662,  0.46860095,
#          0.04553182,  0.41650753,  0.40939995,  0.35318865, -0.04748686,
# ...

# %%
pca_data
# Out:
# array([[-1.68437987, -1.06978155],
#        [-1.13167335,  2.51076016],
#        [ 0.96927454, -0.38369684],
#        ...,
#        [-0.93052044, -1.80642413],
#        [-2.33854638, -0.65107449],
#        [-0.55894251, -0.40071613]])

# %%
plt.figure(figsize=(8,6))
# plt.scatter(x=pca_data[:,0],y=pca_data[:,1],c=cancer['target'])
plt.scatter(x=pca_data[:,0],y=pca_data[:,1],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# /var/folders/cc/_kcvjw313pl6kbf8c3bdtnyc0000gn/T/ipykernel_16214/3747927612.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=pca_data[:,0],y=pca_data[:,1],cmap='plasma')
# Text(0, 0.5, 'Second Principal Component')

# %%
from sklearn.cluster import KMeans

k=5
kmeans = KMeans(n_clusters=k)
clusters = kmeans.fit_predict(pca_data)


plt.figure(figsize=(8,6))

plt.scatter(x=pca_data[:,0], y=pca_data[:,1], c=clusters, cmap='plasma')

plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %% [markdown]
# ## Kmeans seems not to be the best method to use for clustering because we don't see obvious circle clusters. DBSCAN method might be a better option in this case.

# %% [markdown]
# ## Load the dataset

# %%
# !pip install jinja2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('../../Datasets/CC General.csv')

df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# We drop the customer id from the dataset

# %%
# df.drop('CUST_ID')
del df['CUST_ID']

# %% [markdown]
# Check for missing data...

# %%
df.isna().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df['MINIMUM_PAYMENTS'].value_counts()
# Out:
# MINIMUM_PAYMENTS
# 299.351881    2
# 342.286490    1
# 184.464721    1
# 276.486072    1
# 309.140865    1
#              ..
# 181.773223    1
# 711.894455    1
# 256.522546    1
# 127.799107    1
# 88.288956     1
# Name: count, Length: 8636, dtype: int64

# %%
df['MINIMUM_PAYMENTS'].describe()
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
df[df['MINIMUM_PAYMENTS'] == 0].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['CREDIT_LIMIT'].describe()
# Out:
# count     8949.000000
# mean      4494.449450
# std       3638.815725
# min         50.000000
# 25%       1600.000000
# 50%       3000.000000
# 75%       6500.000000
# max      30000.000000
# Name: CREDIT_LIMIT, dtype: float64

# %% [markdown]
# ### Fill missing data with zeros

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# ## Scale data

# %% [markdown]
# create scaler

# %%
scaler = StandardScaler()

# %%
#scale the data set
scaled_df = scaler.fit_transform(df)

scaled_df
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.2973097 ,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.10204243,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.08848934,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.32175099,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.33316552,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.31923775,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# ## Perform PCA with ALL columns and plot number of components to capture 85% of variance of the original data

# %%
## Reduce the dimensions of our dataset

# create the object PCA
# this is a discovery step, we don't know how many components will be good.
pca = PCA()


pca.fit(scaled_df)
# Out:
# PCA()

# %% [markdown]
# See the principal components...

# %%
components = pca.explained_variance_ratio_
components
# Out:
# array([2.73022794e-01, 2.03198080e-01, 8.82521348e-02, 7.47922291e-02,
#        6.20419660e-02, 5.73451642e-02, 4.88066019e-02, 4.32366782e-02,
#        3.77970659e-02, 3.07995556e-02, 2.37243719e-02, 1.77334350e-02,
#        1.42870424e-02, 1.21666759e-02, 1.01251295e-02, 2.67039035e-03,
#        6.85228665e-07])

# %%
commulative = np.cumsum(components) #add the comulative values in the array
commulative
# Out:
# array([0.27302279, 0.47622087, 0.56447301, 0.63926524, 0.7013072 ,
#        0.75865237, 0.80745897, 0.85069565, 0.88849271, 0.91929227,
#        0.94301664, 0.96075008, 0.97503712, 0.98720379, 0.99732892,
#        0.99999931, 1.        ])

# %% [markdown]
# ## We can see that the first 8 components capture 85% of variance from the original dataset.

# %%
plt.plot(commulative)

# %% [markdown]
# ## Vizualize the principal components

# %%
loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
loading_matrix = pd.DataFrame(loadings, index=df.columns)

loading_matrix.style.background_gradient(cmap='RdYlGn', axis=None)
# loading_matrix.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_2bb21_row0_col0 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_2bb21_row0_col1 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_2bb21_row0_col2 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_2bb21_row0_col3, #T_2bb21_row2_col2, #T_2bb21_row14_col1 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_2bb21_row0_col4, #T_2bb21_row2_col12, #T_2bb21_row9_col5, #T_2bb21_row15_col12 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_2bb21_row0_col5, #T_2bb21_row2_col11, #T_2bb21_row7_col3, #T_2bb21_row13_col14, #T_2bb21_row16_col9, #T_2bb21_row16_col10, #T_2bb21_row16_col12 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_2bb21_row0_col6 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_2bb21_row0_col7 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_2bb21_row0_col8, #T_2bb21_row3_col3, #T_2bb21_row5_col4, #T_2bb21_row11_col5, #T_2bb21_row11_col6, #T_2bb21_row12_col4, #T_2bb21_row12_col10 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_2bb21_row0_col9, #T_2bb21_row2_col7, #T_2bb21_row7_col13, #T_2bb21_row9_col11, #T_2bb21_row16_col4 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_2bb21_row0_col10, #T_2bb21_row0_col14, #T_2bb21_row1_col6, #T_2bb21_row6_col12 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_2bb21_row0_col11, #T_2bb21_row5_col9, #T_2bb21_row8_col3 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_2bb21_row0_col12 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_2bb21_row0_col13, #T_2bb21_row7_col9, #T_2bb21_row13_col7, #T_2bb21_row16_col7 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_2bb21_row0_col15, #T_2bb21_row0_col16, #T_2bb21_row1_col15, #T_2bb21_row1_col16, #T_2bb21_row2_col16, #T_2bb21_row3_col12, #T_2bb21_row3_col15, #T_2bb21_row5_col15, #T_2bb21_row5_col16, #T_2bb21_row6_col16, #T_2bb21_row7_col16, #T_2bb21_row8_col16, #T_2bb21_row9_col16, #T_2bb21_row10_col15, #T_2bb21_row10_col16, #T_2bb21_row11_col16, #T_2bb21_row12_col16, #T_2bb21_row13_col16, #T_2bb21_row14_col9, #T_2bb21_row14_col15, #T_2bb21_row14_col16, #T_2bb21_row15_col15, #T_2bb21_row15_col16, #T_2bb21_row16_col16 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_2bb21_row1_col0 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_2bb21_row1_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_2bb21_row1_col2 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_2bb21_row1_col3, #T_2bb21_row2_col5, #T_2bb21_row2_col6, #T_2bb21_row4_col8, #T_2bb21_row8_col4, #T_2bb21_row8_col10, #T_2bb21_row10_col6, #T_2bb21_row11_col9 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_2bb21_row1_col4 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_2bb21_row1_col5, #T_2bb21_row1_col14, #T_2bb21_row8_col13, #T_2bb21_row9_col12, #T_2bb21_row11_col14 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_2bb21_row1_col7 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_2bb21_row1_col8 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_2bb21_row1_col9 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_2bb21_row1_col10 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_2bb21_row1_col11, #T_2bb21_row2_col3, #T_2bb21_row15_col10 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_2bb21_row1_col12, #T_2bb21_row10_col4, #T_2bb21_row11_col2, #T_2bb21_row11_col7 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_2bb21_row1_col13, #T_2bb21_row2_col14, #T_2bb21_row3_col14, #T_2bb21_row5_col7, #T_2bb21_row7_col5, #T_2bb21_row8_col12, #T_2bb21_row12_col14, #T_2bb21_row16_col13 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_2bb21_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2bb21_row2_col1, #T_2bb21_row6_col10, #T_2bb21_row13_col8, #T_2bb21_row13_col11 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_2bb21_row2_col4, #T_2bb21_row11_col15 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_2bb21_row2_col8, #T_2bb21_row6_col11, #T_2bb21_row7_col11, #T_2bb21_row10_col7, #T_2bb21_row14_col11 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_2bb21_row2_col9, #T_2bb21_row8_col6, #T_2bb21_row9_col7, #T_2bb21_row11_col13 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_2bb21_row2_col10, #T_2bb21_row9_col6, #T_2bb21_row10_col10, #T_2bb21_row12_col8 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_2bb21_row2_col13, #T_2bb21_row3_col13, #T_2bb21_row5_col11, #T_2bb21_row6_col4, #T_2bb21_row10_col0 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_2bb21_row2_col15, #T_2bb21_row3_col16, #T_2bb21_row4_col15, #T_2bb21_row4_col16, #T_2bb21_row6_col13, #T_2bb21_row12_col15, #T_2bb21_row13_col15, #T_2bb21_row15_col13, #T_2bb21_row15_col14, #T_2bb21_row16_col15 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_2bb21_row3_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_2bb21_row3_col1, #T_2bb21_row3_col6, #T_2bb21_row3_col7, #T_2bb21_row10_col11 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_2bb21_row3_col2, #T_2bb21_row13_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_2bb21_row3_col4, #T_2bb21_row13_col10 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_2bb21_row3_col5, #T_2bb21_row12_col11, #T_2bb21_row15_col8, #T_2bb21_row15_col9, #T_2bb21_row16_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_2bb21_row3_col8, #T_2bb21_row5_col12, #T_2bb21_row9_col15 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_2bb21_row3_col9, #T_2bb21_row10_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_2bb21_row3_col10, #T_2bb21_row15_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_2bb21_row3_col11, #T_2bb21_row5_col2, #T_2bb21_row8_col14, #T_2bb21_row11_col3, #T_2bb21_row13_col12, #T_2bb21_row14_col14 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_2bb21_row4_col0 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_2bb21_row4_col1, #T_2bb21_row7_col1 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_2bb21_row4_col2, #T_2bb21_row6_col6, #T_2bb21_row8_col15, #T_2bb21_row11_col10, #T_2bb21_row15_col11 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_2bb21_row4_col3, #T_2bb21_row7_col15 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_2bb21_row4_col4, #T_2bb21_row16_col6 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_2bb21_row4_col5 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_2bb21_row4_col6 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_2bb21_row4_col7, #T_2bb21_row5_col5, #T_2bb21_row8_col7 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_2bb21_row4_col9 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_2bb21_row4_col10, #T_2bb21_row5_col10, #T_2bb21_row6_col3 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_2bb21_row4_col11, #T_2bb21_row12_col3, #T_2bb21_row15_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_2bb21_row4_col12, #T_2bb21_row6_col15, #T_2bb21_row7_col2, #T_2bb21_row9_col13, #T_2bb21_row13_col6, #T_2bb21_row14_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_2bb21_row4_col13, #T_2bb21_row6_col5, #T_2bb21_row8_col8 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_2bb21_row4_col14, #T_2bb21_row6_col14, #T_2bb21_row7_col14, #T_2bb21_row8_col11, #T_2bb21_row14_col10, #T_2bb21_row16_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_2bb21_row5_col0, #T_2bb21_row6_col7, #T_2bb21_row8_col5, #T_2bb21_row10_col12 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_2bb21_row5_col1 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_2bb21_row5_col3 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_2bb21_row5_col6, #T_2bb21_row5_col8, #T_2bb21_row10_col13, #T_2bb21_row11_col1, #T_2bb21_row11_col4, #T_2bb21_row16_col14 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_2bb21_row5_col13, #T_2bb21_row9_col14, #T_2bb21_row15_col6 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_2bb21_row5_col14, #T_2bb21_row16_col2 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_2bb21_row6_col0 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_2bb21_row6_col1 {
#   background-color: #f7814c;
#   co

# %% [markdown]
# ### Perform PCA with 2 principal components to visualize the clustering data

# %%
num_components = 2

pca_final = PCA(n_components=num_components)

pca_data = pca_final.fit_transform(scaled_df)

# %%
pca_final.get_covariance()
# Out:
# array([[ 1.10223168,  0.20218301,  0.21565926,  0.21403257,  0.11659984,
#          0.49769032, -0.08831876,  0.09984674, -0.09338455,  0.4650115 ,
#          0.46491504,  0.13761481,  0.36218712,  0.40624188,  0.22331226,
#         -0.16513028,  0.02869159],
#        [ 0.20218301,  0.7024362 ,  0.21605216,  0.19243804,  0.15724059,
#          0.15453737,  0.08479706,  0.13679633,  0.06661053,  0.12059496,
#          0.13487023,  0.18314718,  0.19331723,  0.22699864,  0.09587106,
#         -0.00731484,  0.03808328],
#        [ 0.21565926,  0.21605216,  1.28366603,  0.58380386,  0.55873921,
#          0.0120456 ,  0.51329466,  0.48832572,  0.43686572, -0.09803773,
#         -0.03233593,  0.64826623,  0.38013366,  0.47306949,  0.12726019,
#          0.19791062,  0.13469241],
#        [ 0.21403257,  0.19243804,  0.58380386,  1.0899046 ,  0.4686043 ,
#          0.04552859,  0.41650888,  0.4094025 ,  0.35318798, -0.04749068,
#          0.0066244 ,  0.54385581,  0.33904757,  0.41875542,  0.12080713,
#          0.1512154 ,  0.11300579],
#        [ 0.11659984,  0.15724059,  0.55873921,  0.4686043 ,  1.05377782,
#         -0.05522794,  0.44838574,  0.40238387,  0.38401825, -0.14459934,
#         -0.0886805 ,  0.53350956,  0.27580815,  0.34909197,  0.07890702,
#          0.19012866,  0.11083603],
#        [ 0.49769032,  0.15453737,  0.0120456 ,  0.04552859, -0.05522794,
#          1.1469159 , -0.26955464, -0.05057329, -0.24981419,  0.55324674,
#          0.53129312, -0.06146597,  0.27912926,  0.29755428,  0.20771773,
#         -0.25069249, -0.01266025],
#        [-0.08831876,  0.08479706,  0.51329466,  0.41650888,  0.44838574,
#         -0.26955464,  1.11580167,  0.39304023,  0.45464799, -0.35242286,
#         -0.29191174,  0.51891573,  0.14555627,  0.20623122, -0.00882093,
#          0.27522514,  0.10776106],
#        [ 0.09984674,  0.13679633,  0.48832572,  0.4094025 ,  0.40238387,
#         -0.05057329,  0.39304023,  0.94560364,  0.33669662, -0.12868999,
#         -0.07972187,  0.46657896,  0.23991433,  0.30389273,  0.06810637,
#          0.16722767,  0.09693082],
#        [-0.09338455,  0.06661053,  0.43686572,  0.35318798,  0.38401825,
#         -0.24981419,  0.45464799,  0.33669662,  0.99012876, -0.32041482,
#         -0.26806175,  0.44433412,  0.11383337,  0.16485421, -0.01508636,
#          0.24361761,  0.09226922],
#        [ 0.4650115 ,  0.12059496, -0.09803773, -0.04749068, -0.14459934,
#          0.55324674, -0.35242286, -0.12868999, -0.32041482,  1.16451294,
#          0.53831341, -0.16514825,  0.21943447,  0.22309086,  0.18813316,
#         -0.28315752, -0.03420227],
#        [ 0.46491504,  0.13487023, -0.03233593,  0.0066244 , -0.0886805 ,
#          0.53129312, -0.29191174, -0.07972187, -0.26806175,  0.53831341,
#          1.10670047, -0.10037858,  0.24424922,  0.2560533 ,  0.19166728,
#         -0.25369588, -0.02074949],
#        [ 0.13761481,  0.18314718,  0.64826623,  0.54385581,  0.53350956,
#         -0.06146597,  0.51891573,  0.46657896,  0.44433412, -0.16514825,
#         -0.10037858,  1.21233304,  0.32128762,  0.40639307,  0.0925206 ,
#          0.21939306,  0.12852445],
#        [ 0.36218712,  0.19331723,  0.38013366,  0.33904757,  0.27580815,
#          0.27912926,  0.14555627,  0.23991433,  0.11383337,  0.21943447,
#          0.24424922,  0.32128762,  0.93737677,  0.40317457,  0.17136646,
#         -0.01619182,  0.06680955],
#        [ 0.40624188,  0.22699864,  0.47306949,  0.41875542,  0.34909197,
#          0.29755428,  0.20623122,  0.30389273,  0.16485421,  0.22309086,
#          0.2560533 ,  0.40639307,  0.40317457,  1.06936603,  0.19475112,
#          0.00274353,  0.08449555],
#        [ 0.22331226,  0.09587106,  0.12726019,  0.12080713,  0.07890702,
#          0.20771773, -0.00882093,  0.06810637, -0.01508636,  0.18813316,
#          0.19166728,  0.0925206 ,  0.17136646,  0.19475112,  0.69351411,
#         -0.05793536,  0.01926446],
#        [-0.16513028, -0.00731484,  0.19791062,  0.1512154 ,  0.19012866,
#         -0.25069249,  0.27522514,  0.16722767,  0.24361761, -0.28315752,
#         -0.25369588,  0.21939306, -0.01619182,  0.00274353, -0.05793536,
#          0.76724637,  0.04553313],
#        [ 0.02869159,  0.03808328,  0.13469241,  0.11300579,  0.11083603,
#         -0.01266025,  0.10776106,  0.09693082,  0.09226922, -0.03420227,
#         -0.02074949,  0.12852445,  0.06680955,  0.08449555,  0.01926446,
#          0.04553313,  0.62038362]])

# %%
pca_data
# Out:
# array([[-1.68437703, -1.06977766],
#        [-1.13167202,  2.51070516],
#        [ 0.96932137, -0.38351304],
#        ...,
#        [-0.93053723, -1.80649439],
#        [-2.33856521, -0.65113437],
#        [-0.55894137, -0.4006989 ]])

# %%
plt.figure(figsize=(8,6))
# plt.scatter(x=pca_data[:,0],y=pca_data[:,1],c=cancer['target'])
plt.scatter(x=pca_data[:,0],y=pca_data[:,1],cmap='plasma')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# /var/folders/cc/_kcvjw313pl6kbf8c3bdtnyc0000gn/T/ipykernel_16214/3747927612.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=pca_data[:,0],y=pca_data[:,1],cmap='plasma')
# Text(0, 0.5, 'Second Principal Component')

# %%
from sklearn.cluster import KMeans

k=3
kmeans = KMeans(n_clusters=k)
clusters = kmeans.fit_predict(pca_data)


plt.figure(figsize=(8,6))

plt.scatter(x=pca_data[:,0], y=pca_data[:,1], c=clusters, cmap='plasma')

plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %% [markdown]
# ## Kmeans seems not to be the best method to use for clustering because we don't see obvious circle clusters. DBSCAN method might be a better option in this case.
